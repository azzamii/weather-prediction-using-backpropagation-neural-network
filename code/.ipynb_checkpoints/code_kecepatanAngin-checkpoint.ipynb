# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

df = pd.read_excel('cepatAngin.xlsx')
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\AZZAMI~1\AppData\Local\Temp/ipykernel_2696/2396245887.py in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 df = pd.read_excel('dataRAW/cepatAngin.xlsx')
#       7 display(df)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
display(df.isnull().sum()) #mengecek NaN
display(df.info())
# Out:
# angin18     0
# angin19     0
# angin20    13
# angin21     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   angin18  365 non-null    int64
#  1   angin19  365 non-null    int64
#  2   angin20  352 non-null    float64
#  3   angin21  365 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 11.5 KB
# None

# %%
df = df.dropna(axis=0) #drop nilai 0
display(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 364
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   angin18  352 non-null    int64
#  1   angin19  352 non-null    int64
#  2   angin20  352 non-null    float64
#  3   angin21  352 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 13.8 KB
# None
#      angin18  angin19  angin20  angin21
# 0          2        2      2.0        3
# 1          2        4      3.0        2
# 2          1        4      3.0        2
# 3          1        3      4.0        3
# 4          2        3      3.0        2
# ..       ...      ...      ...      ...
# 360        2        1      2.0        1
# 361        2        1      3.0        1
# 362        2        2      2.0        2
# 363        4        1      3.0        1
# 364        3        0      3.0        2
#
# [352 rows x 4 columns]

# %%
plt.boxplot(df['angin18'])
plt.show()
plt.boxplot(df['angin19'])
plt.show()
plt.boxplot(df['angin20'])
plt.show()
plt.boxplot(df['angin21'])
plt.show()

# %%
Q1 = df['angin18'].quantile(0.25)
Q3 = df['angin18'].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df['angin18'] < (Q1 - 1.5 * IQR)) |(df['angin18'] > (Q3 + 1.5 * IQR)))]

# %%
Q1 = df['angin19'].quantile(0.25)
Q3 = df['angin19'].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df['angin19'] < (Q1 - 1.5 * IQR)) |(df['angin19'] > (Q3 + 1.5 * IQR)))]

# %%
Q1 = df['angin20'].quantile(0.25)
Q3 = df['angin20'].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df['angin20'] < (Q1 - 1.5 * IQR)) |(df['angin20'] > (Q3 + 1.5 * IQR)))]

# %%
Q1 = df['angin21'].quantile(0.25)
Q3 = df['angin21'].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df['angin21'] < (Q1 - 1.5 * IQR)) |(df['angin21'] > (Q3 + 1.5 * IQR)))]

# %%
df = df.dropna(axis=0) #drop nilai 0
display(df.info())
display(df)
#df.to_excel('cleansingAnginRaw.xlsx')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315 entries, 0 to 364
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   angin18  315 non-null    int64
#  1   angin19  315 non-null    int64
#  2   angin20  315 non-null    float64
#  3   angin21  315 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 12.3 KB
# None
#      angin18  angin19  angin20  angin21
# 0          2        2      2.0        3
# 4          2        3      3.0        2
# 6          2        1      1.0        3
# 8          1        2      2.0        3
# 9          3        1      3.0        2
# ..       ...      ...      ...      ...
# 359        2        1      2.0        1
# 360        2        1      2.0        1
# 361        2        1      3.0        1
# 362        2        2      2.0        2
# 364        3        0      3.0        2
#
# [315 rows x 4 columns]

# %%
df = pd.read_excel('cleansingAnginFix.xlsx')
display(df)
# Out:
#       x  y
# 0     2  2
# 1     2  2
# 2     2  1
# 3     1  3
# 4     3  2
# ...  .. ..
# 1254  1  1
# 1255  1  1
# 1256  1  1
# 1257  1  2
# 1258  2  2
#
# [1259 rows x 2 columns]

# %%
x = df.iloc[:,0:1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.75, random_state=0)

# %%
import tensorflow as tf #bpnn

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(units=1, activation='relu'))
model.add(tf.keras.layers.Dense(units=6, activation='relu'))
model.add(tf.keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.001))

model.fit(x_train, y_train, epochs=10000, batch_size=100)
# Out:
# Epoch 1/10000
# 10/10 [==============================] - 0s 772us/step - loss: 2.3281
# Epoch 2/10000
# 10/10 [==============================] - 0s 459us/step - loss: 2.1168
# Epoch 3/10000
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9472
# Epoch 4/10000
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7857
# Epoch 5/10000
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6381
# Epoch 6/10000
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5121
# Epoch 7/10000
# 10/10 [==============================] - 0s 0s/step - loss: 1.4148
# Epoch 8/10000
# 10/10 [==============================] - 0s 0s/step - loss: 1.3264
# Epoch 9/10000
# 10/10 [==============================] - 0s 0s/step - loss: 1.2424
# Epoch 10/10000
# 10/10 [==============================] - 0s 430us/step - loss: 1.1614
# Epoch 11/10000
# 10/10 [==============================] - 0s 556us/step - loss: 1.0851
# Epoch 12/10000
# ...

# %%
ypredik = model.predict(x_test)
column_values = [
    'Data fix',
    'Data predict'
]

df = pd.DataFrame(columns = column_values) 
df['Data fix'] = y_test
df['Data predict'] = ypredik
print(df)
df.to_excel('prediksi_angin.xlsx')
# Out:
# 10/10 [==============================] - 0s 2ms/step
#      Data fix  Data predict
# 0           3      1.796318
# 1           2      2.152489
# 2           2      1.440148
# 3           2      1.796318
# 4           2      1.440148
# ..        ...           ...
# 310         1      1.440148
# 311         1      1.440148
# 312         1      1.796318
# 313         2      2.152489
# 314         2      1.796318
#
# [315 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ypredik, y_test)
print(mse)
# Out:
# 0.4370177969810627

# %%
df['Data fix'].plot(figsize=(16,6), color='blue', label='data aktual')
df['Data predict'].plot(figsize=(16,6), color='red', label='hasil prediksi')
plt.title('hasil prediksi Kecepatan Angin rata-rata')
plt.xlabel('waktu')
plt.ylabel('kecepatan angin')
plt.legend(loc='lower left')

# %%
df.describe()
# Out:
#          Data fix  Data predict
# count  315.000000    315.000000
# mean     1.752381      1.675336
# std      0.706399      0.270158
# min      0.000000      1.083977
# 25%      1.000000      1.440148
# 50%      2.000000      1.796318
# 75%      2.000000      1.796318
# max      3.000000      2.152489

# %%
plotdata = df.mean()
ax = plotdata.plot(kind="bar", color=['blue', 'red'], rot=0, x='pillar', y='%')
ax.bar_label(ax.containers[0], label_type='edge')
plt.tight_layout()
plt.title("rata-rata kecepatan angin")
plt.ylabel("kecepatan angin dalam meter per detik")
# Out:
# Text(20.625, 0.5, 'kecepatan angin dalam meter per detik')
